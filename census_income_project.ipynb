# %% [markdown]
# # CENSUS INCOME PROJECT

# %% [markdown]
# LOADING THE IMPORTANT MODULES

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings 
warnings.filterwarnings('ignore')

# %% [markdown]
# Loading The Dataset

# %%
ci=pd.read_csv('census_income.csv')

# %%
ci
# Out:
#        Age          Workclass  Fnlwgt    Education  Education_num  \
# 0       50   Self-emp-not-inc   83311    Bachelors             13
# 1       38            Private  215646      HS-grad              9
# 2       53            Private  234721         11th              7
# 3       28            Private  338409    Bachelors             13
# 4       37            Private  284582      Masters             14
# ...    ...                ...     ...          ...            ...
# 32555   27            Private  257302   Assoc-acdm             12
# 32556   40            Private  154374      HS-grad              9
# 32557   58            Private  151910      HS-grad              9
# 32558   22            Private  201490      HS-grad              9
# 32559   52       Self-emp-inc  287927      HS-grad              9
#
#             Marital_status          Occupation    Relationship    Race  \
# 0       Married-civ-spouse     Exec-managerial         Husband   White
# ...

# %%
ci.shape
# Out:
# (32560, 15)

# %% [markdown]
# There are 32566 rows and 15 columns in dataset.

# %%
ci.head()
# Out:
#    Age          Workclass  Fnlwgt   Education  Education_num  \
# 0   50   Self-emp-not-inc   83311   Bachelors             13
# 1   38            Private  215646     HS-grad              9
# 2   53            Private  234721        11th              7
# 3   28            Private  338409   Bachelors             13
# 4   37            Private  284582     Masters             14
#
#         Marital_status          Occupation    Relationship    Race      Sex  \
# 0   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 1             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 2   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 3   Married-civ-spouse      Prof-specialty            Wife   Black   Female
# 4   Married-civ-spouse     Exec-managerial            Wife   White   Female
#
#    Capital_gain  Capital_loss  Hours_per_week  Native_country  Income
# 0             0             0              13   United-States   <=50K
# ...

# %% [markdown]
# First 5 rows.

# %%
ci.tail()
# Out:
#        Age      Workclass  Fnlwgt    Education  Education_num  \
# 32555   27        Private  257302   Assoc-acdm             12
# 32556   40        Private  154374      HS-grad              9
# 32557   58        Private  151910      HS-grad              9
# 32558   22        Private  201490      HS-grad              9
# 32559   52   Self-emp-inc  287927      HS-grad              9
#
#             Marital_status          Occupation Relationship    Race      Sex  \
# 32555   Married-civ-spouse        Tech-support         Wife   White   Female
# 32556   Married-civ-spouse   Machine-op-inspct      Husband   White     Male
# 32557              Widowed        Adm-clerical    Unmarried   White   Female
# 32558        Never-married        Adm-clerical    Own-child   White     Male
# 32559   Married-civ-spouse     Exec-managerial         Wife   White   Female
#
#        Capital_gain  Capital_loss  Hours_per_week  Native_country  Income
# ...

# %% [markdown]
# Last 5 rows.

# %%
ci.sample(5)
# Out:
#        Age     Workclass  Fnlwgt      Education  Education_num  \
# 14646   20       Private  137300      Assoc-voc             11
# 21823   34     State-gov  327902      Bachelors             13
# 5137    41   Federal-gov   57924   Some-college             10
# 7851    41       Private   33310        HS-grad              9
# 12715   28       Private  224506   Some-college             10
#
#             Marital_status          Occupation    Relationship    Race  \
# 14646        Never-married   Machine-op-inspct       Unmarried   White
# 21823   Married-civ-spouse      Prof-specialty         Husband   White
# 5137         Never-married     Protective-serv       Own-child   White
# 7851         Never-married        Adm-clerical   Not-in-family   White
# 12715   Married-civ-spouse               Sales         Husband   Black
#
#            Sex  Capital_gain  Capital_loss  Hours_per_week  Native_country  \
# 14646   Female             0             0              40   United-States
# ...

# %% [markdown]
# Any Random 5 sample of dataset.

# %%
ci.dtypes
# Out:
# Age                int64
# Workclass         object
# Fnlwgt             int64
# Education         object
# Education_num      int64
# Marital_status    object
# Occupation        object
# Relationship      object
# Race              object
# Sex               object
# Capital_gain       int64
# Capital_loss       int64
# Hours_per_week     int64
# Native_country    object
# Income            object
# dtype: object

# %% [markdown]
# 2 types of data,
# int,object.

# %%
ci.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32560 entries, 0 to 32559
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             32560 non-null  int64
#  1   Workclass       32560 non-null  object
#  2   Fnlwgt          32560 non-null  int64
#  3   Education       32560 non-null  object
#  4   Education_num   32560 non-null  int64
#  5   Marital_status  32560 non-null  object
#  6   Occupation      32560 non-null  object
#  7   Relationship    32560 non-null  object
#  8   Race            32560 non-null  object
#  9   Sex             32560 non-null  object
#  10  Capital_gain    32560 non-null  int64
#  11  Capital_loss    32560 non-null  int64
#  12  Hours_per_week  32560 non-null  int64
#  13  Native_country  32560 non-null  object
#  14  Income          32560 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %% [markdown]
# 6 int data and 9 object data in census_income dataset.

# %% [markdown]
# # Checking the null values

# %%
sns.heatmap(ci.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# No blanks in heatmap it means no null values in dataset.

# %%
ci.isnull().sum()
# Out:
# Age               0
# Workclass         0
# Fnlwgt            0
# Education         0
# Education_num     0
# Marital_status    0
# Occupation        0
# Relationship      0
# Race              0
# Sex               0
# Capital_gain      0
# Capital_loss      0
# Hours_per_week    0
# Native_country    0
# Income            0
# dtype: int64

# %% [markdown]
# No null values in datset.

# %% [markdown]
# # Statistical Summary

# %%
ci.describe()
# Out:
#                 Age        Fnlwgt  Education_num  Capital_gain  Capital_loss  \
# count  32560.000000  3.256000e+04   32560.000000  32560.000000  32560.000000
# mean      38.581634  1.897818e+05      10.080590   1077.615172     87.306511
# std       13.640642  1.055498e+05       2.572709   7385.402999    402.966116
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178315e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783630e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370545e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        Hours_per_week
# count    32560.000000
# mean        40.437469
# std         12.347618
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %% [markdown]
# High variance in mean and median in capital_gain and capital_loss.
#
# High varince in 75% and 100% in most of the column. and Fnlwgt column is not showing correctly so we should drop this column.

# %%
ci.corr().sum().sort_values(ascending=False)
# Out:
# Education_num     1.344054
# Hours_per_week    1.330778
# Capital_gain      1.247533
# Age               1.164086
# Capital_loss      1.150090
# Fnlwgt            0.851602
# dtype: float64

# %% [markdown]
# Fnlwgt is less correlated.

# %%
sns.heatmap(ci.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# All columns are very less correlated.

# %% [markdown]
# # Data Visualization

# %%
ci.keys()
# Out:
# Index(['Age', 'Workclass', 'Fnlwgt', 'Education', 'Education_num',
#        'Marital_status', 'Occupation', 'Relationship', 'Race', 'Sex',
#        'Capital_gain', 'Capital_loss', 'Hours_per_week', 'Native_country',
#        'Income'],
#       dtype='object')

# %%
ci["Age"].value_counts().sort_values(ascending=False)
# Out:
# 36    898
# 31    888
# 34    886
# 23    877
# 35    876
#      ...
# 83      6
# 88      3
# 85      3
# 86      1
# 87      1
# Name: Age, Length: 73, dtype: int64

# %%
sns.histplot(ci["Age"])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Count'>

# %% [markdown]
# Age data is sked.

# %%
sns.catplot("Age",data=ci,kind='violin')

# %% [markdown]
# Observation:
#
# 20 to 50 Age of people are higher in census dataset.

# %%
ci["Workclass"].value_counts().sort_values(ascending=False)
# Out:
#  Private             22696
#  Self-emp-not-inc     2541
#  Local-gov            2093
#  ?                    1836
#  State-gov            1297
#  Self-emp-inc         1116
#  Federal-gov           960
#  Without-pay            14
#  Never-worked            7
# Name: Workclass, dtype: int64

# %%
plt.figure(figsize=(10,3))
sns.countplot("Workclass",data=ci)
# Out:
# <AxesSubplot:xlabel='Workclass', ylabel='count'>

# %% [markdown]
# Observation:
#
# people who are working on private sector are higher in census_income_project.

# %%
ci["Fnlwgt"].value_counts().sort_values(ascending=False)
# Out:
# 164190    13
# 123011    13
# 203488    13
# 148995    12
# 126675    12
#           ..
# 242804     1
# 231573     1
# 171234     1
# 206325     1
# 257302     1
# Name: Fnlwgt, Length: 21647, dtype: int64

# %%
sns.histplot(ci["Fnlwgt"])
# Out:
# <AxesSubplot:xlabel='Fnlwgt', ylabel='Count'>

# %% [markdown]
# Fnlwgt data is sked.

# %%
sns.catplot("Fnlwgt",data=ci,kind='boxen')

# %% [markdown]
# Observation:
#
# Fnlwgt data is higher in 0.1 to 0.3.

# %%
ci["Education"].value_counts().sort_values(ascending=False)
# Out:
#  HS-grad         10501
#  Some-college     7291
#  Bachelors        5354
#  Masters          1723
#  Assoc-voc        1382
#  11th             1175
#  Assoc-acdm       1067
#  10th              933
#  7th-8th           646
#  Prof-school       576
#  9th               514
#  12th              433
#  Doctorate         413
#  5th-6th           333
#  1st-4th           168
#  Preschool          51
# Name: Education, dtype: int64

# %%
plt.figure(figsize=(20,5))
sns.countplot("Education",data=ci)
# Out:
# <AxesSubplot:xlabel='Education', ylabel='count'>

# %%
sns.catplot("Education",data=ci,height=5,aspect=4)

# %% [markdown]
# Observation:
#
# people who have HS-grad and some-college type of Education are higher.

# %%
ci["Education_num"].value_counts().sort_values(ascending=False)
# Out:
# 9     10501
# 10     7291
# 13     5354
# 14     1723
# 11     1382
# 7      1175
# 12     1067
# 6       933
# 4       646
# 15      576
# 5       514
# 8       433
# 16      413
# 3       333
# 2       168
# 1        51
# Name: Education_num, dtype: int64

# %%
sns.catplot('Education_num',data=ci,kind="boxen")

# %%
sns.histplot(ci["Education_num"])
# Out:
# <AxesSubplot:xlabel='Education_num', ylabel='Count'>

# %% [markdown]
# Observation:
#
# Education_num are higher in between 9 to 14,it means most of the people are educated.

# %%
ci["Marital_status"].value_counts().sort_values(ascending=False)
# Out:
#  Married-civ-spouse       14976
#  Never-married            10682
#  Divorced                  4443
#  Separated                 1025
#  Widowed                    993
#  Married-spouse-absent      418
#  Married-AF-spouse           23
# Name: Marital_status, dtype: int64

# %%
plt.figure(figsize=(15,5))
sns.countplot("Marital_status",data=ci)
# Out:
# <AxesSubplot:xlabel='Marital_status', ylabel='count'>

# %% [markdown]
# Observation:
#
# Married-civ-spouse and Never-married people are higher in census income dataset.

# %%
ci["Occupation"].value_counts().sort_values(ascending=False)
# Out:
#  Prof-specialty       4140
#  Craft-repair         4099
#  Exec-managerial      4066
#  Adm-clerical         3769
#  Sales                3650
#  Other-service        3295
#  Machine-op-inspct    2002
#  ?                    1843
#  Transport-moving     1597
#  Handlers-cleaners    1370
#  Farming-fishing       994
#  Tech-support          928
#  Protective-serv       649
#  Priv-house-serv       149
#  Armed-Forces            9
# Name: Occupation, dtype: int64

# %%
plt.figure(figsize=(25,8))
sns.countplot("Occupation",data=ci)
# Out:
# <AxesSubplot:xlabel='Occupation', ylabel='count'>

# %% [markdown]
# Observation;
#
# Armed-Forces Occupation is lowest Occupation.

# %%
ci["Relationship"].value_counts().sort_values(ascending=False)
# Out:
#  Husband           13193
#  Not-in-family      8304
#  Own-child          5068
#  Unmarried          3446
#  Wife               1568
#  Other-relative      981
# Name: Relationship, dtype: int64

# %%
sns.countplot("Relationship",data=ci)
# Out:
# <AxesSubplot:xlabel='Relationship', ylabel='count'>

# %% [markdown]
# Obserbvation:
#
# Relationship of husband is higher other-relatives is lower.

# %%
ci["Race"].value_counts().sort_values(ascending=False)
# Out:
#  White                 27815
#  Black                  3124
#  Asian-Pac-Islander     1039
#  Amer-Indian-Eskimo      311
#  Other                   271
# Name: Race, dtype: int64

# %%
plt.figure(figsize=(10,5))
sns.countplot("Race",data=ci)
# Out:
# <AxesSubplot:xlabel='Race', ylabel='count'>

# %% [markdown]
# Observation:
#
# White Race of people are the most.

# %%
ci["Sex"].value_counts().sort_values(ascending=False)
# Out:
#  Male      21789
#  Female    10771
# Name: Sex, dtype: int64

# %%
sns.countplot("Sex",data=ci)
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='count'>

# %% [markdown]
# Observation:
#
# Male are higher and Female are less in census income dataset.

# %%
ci["Capital_gain"].value_counts().sort_values(ascending=False)
# Out:
# 0        29849
# 15024      347
# 7688       284
# 7298       246
# 99999      159
#          ...
# 1111         1
# 2538         1
# 22040        1
# 4931         1
# 5060         1
# Name: Capital_gain, Length: 119, dtype: int64

# %%
sns.stripplot("Capital_gain",data=ci)
# Out:
# <AxesSubplot:xlabel='Capital_gain'>

# %%
sns.catplot('Capital_gain',data=ci,kind="violin")

# %% [markdown]
# Observation;
#
# Capital_gain 0 is higher.

# %%
ci["Capital_loss"].value_counts().sort_values(ascending=False)
# Out:
# 0       31041
# 1902      202
# 1977      168
# 1887      159
# 1848       51
#         ...
# 1944        1
# 2467        1
# 2472        1
# 2201        1
# 1411        1
# Name: Capital_loss, Length: 92, dtype: int64

# %%
sns.catplot("Capital_loss",data=ci)

# %%
sns.histplot(ci["Capital_loss"])
# Out:
# <AxesSubplot:xlabel='Capital_loss', ylabel='Count'>

# %% [markdown]
# Observation:
#
# Capital_loss 0 is the most.

# %%
ci["Hours_per_week"].value_counts().sort_values(ascending=False)
# Out:
# 40    15216
# 50     2819
# 45     1824
# 60     1475
# 35     1297
#       ...
# 82        1
# 94        1
# 92        1
# 74        1
# 87        1
# Name: Hours_per_week, Length: 94, dtype: int64

# %%
sns.distplot(ci["Hours_per_week"],kde=False,bins=10)
# Out:
# <AxesSubplot:xlabel='Hours_per_week'>

# %% [markdown]
# Observation:
#
# Hours_per_week 40 is the most.

# %%
ci["Native_country"].value_counts().sort_values(ascending=False)
# Out:
#  United-States                 29169
#  Mexico                          643
#  ?                               583
#  Philippines                     198
#  Germany                         137
#  Canada                          121
#  Puerto-Rico                     114
#  El-Salvador                     106
#  India                           100
#  Cuba                             95
#  England                          90
#  Jamaica                          81
#  South                            80
#  China                            75
#  Italy                            73
#  Dominican-Republic               70
#  Vietnam                          67
#  Guatemala                        64
#  Japan                            62
#  Poland                           60
#  Columbia                         59
#  Taiwan                           51
#  Haiti                            44
#  Iran                             43
#  Portugal                         37
# ...

# %%
plt.figure(figsize=(40,10))
sns.histplot(ci["Native_country"])
# Out:
# <AxesSubplot:xlabel='Native_country', ylabel='Count'>

# %%
sns.catplot("Native_country",data=ci,kind='count',height=7,aspect=5)

# %% [markdown]
# Observation;
#
# United-States is the most.

# %%
ci["Income"].value_counts().sort_values(ascending=False)
# Out:
#  <=50K    24719
#  >50K      7841
# Name: Income, dtype: int64

# %%
sns.countplot("Income",data=ci)
# Out:
# <AxesSubplot:xlabel='Income', ylabel='count'>

# %% [markdown]
# Observation;
#
# People whose salary is 50000 or more, those people are more.

# %%
ci.columns
# Out:
# Index(['Age', 'Workclass', 'Fnlwgt', 'Education', 'Education_num',
#        'Marital_status', 'Occupation', 'Relationship', 'Race', 'Sex',
#        'Capital_gain', 'Capital_loss', 'Hours_per_week', 'Native_country',
#        'Income'],
#       dtype='object')

# %%
ci.head(5).T
# Out:
#                                   0                   1                    2  \
# Age                              50                  38                   53
# Workclass          Self-emp-not-inc             Private              Private
# Fnlwgt                        83311              215646               234721
# Education                 Bachelors             HS-grad                 11th
# Education_num                    13                   9                    7
# Marital_status   Married-civ-spouse            Divorced   Married-civ-spouse
# Occupation          Exec-managerial   Handlers-cleaners    Handlers-cleaners
# Relationship                Husband       Not-in-family              Husband
# Race                          White               White                Black
# Sex                            Male                Male                 Male
# Capital_gain                      0                   0                    0
# ...

# %%
sns.catplot("Income","Workclass",data=ci)

# %% [markdown]
# The income of people with Never-Worked and Without-Pay is less than 50000.

# %%
sns.set_context("notebook")
sns.lineplot("Income","Workclass",data=ci)
# Out:
# <AxesSubplot:xlabel='Income', ylabel='Workclass'>

# %% [markdown]
# Income is coming down with workclasses.

# %%
sns.relplot("Income","Fnlwgt",data=ci)

# %%
sns.set_context("notebook")
sns.lineplot("Income","Fnlwgt",data=ci)
# Out:
# <AxesSubplot:xlabel='Income', ylabel='Fnlwgt'>

# %% [markdown]
# Income is coming down with Fnlwgt.

# %%
sns.catplot("Income","Education",data=ci)

# %%
sns.lineplot("Income","Education",data=ci)
# Out:
# <AxesSubplot:xlabel='Income', ylabel='Education'>

# %% [markdown]
# Income is increasing with education.

# %%
sns.violinplot("Income","Education_num",data=ci)
# Out:
# <AxesSubplot:xlabel='Income', ylabel='Education_num'>

# %% [markdown]
# Income is higher in 12.5 to 17.5 in Education_num.

# %%
sns.lineplot("Income",'Education_num',data=ci)
# Out:
# <AxesSubplot:xlabel='Income', ylabel='Education_num'>

# %% [markdown]
# Income is increasing with education_num.

# %%
sns.relplot("Income","Marital_status",data=ci)

# %%
sns.jointplot("Income","Marital_status",data=ci)

# %% [markdown]
# Income is greater than 50k of Married-civ-spouse and nevr-married of marital_status people.

# %%
sns.lineplot("Income","Marital_status",data=ci)
# Out:
# <AxesSubplot:xlabel='Income', ylabel='Marital_status'>

# %% [markdown]
# Income is increasing with marital_status.

# %%
sns.catplot("Income","Occupation",data=ci)

# %% [markdown]
# priv-house-serv and Armed-Forces of Occupation people's salary is lower than 50k.

# %%
sns.lineplot("Income","Occupation",data=ci)
# Out:
# <AxesSubplot:xlabel='Income', ylabel='Occupation'>

# %% [markdown]
# Adm-clerical Occupation of people's Income is higher than 50k.

# %%
sns.jointplot("Income","Race",data=ci)

# %%
sns.stripplot("Income","Race",data=ci)
# Out:
# <AxesSubplot:xlabel='Income', ylabel='Race'>

# %% [markdown]
# White Race of people Income is higher than 50k and other people's Income is lower tha 50k.

# %%
sns.lineplot("Income","Race",data=ci)
# Out:
# <AxesSubplot:xlabel='Income', ylabel='Race'>

# %% [markdown]
# Income is increasing with Race.

# %%
sns.catplot("Income","Capital_gain",data=ci)

# %%
sns.lineplot("Income","Capital_gain",data=ci)
# Out:
# <AxesSubplot:xlabel='Income', ylabel='Capital_gain'>

# %% [markdown]
# Income is increasing with Capital_gain.

# %%
sns.catplot("Income","Capital_loss",data=ci)

# %% [markdown]
# Income is lower than 50k is higher in Capital_loss.

# %%
sns.catplot("Income","Hours_per_week",data=ci)

# %%
sns.jointplot("Income","Hours_per_week",data=ci)

# %% [markdown]
# Income is higher than 50k in Hours_per_week.

# %%
sns.lineplot("Income","Hours_per_week",data=ci)
# Out:
# <AxesSubplot:xlabel='Income', ylabel='Hours_per_week'>

# %% [markdown]
# Income is increasing with Hours_per_week.

# %%
sns.catplot("Income","Native_country",data=ci)

# %%
sns.jointplot("Income","Native_country",data=ci)

# %% [markdown]
# United-states Income is higher than 50k and other people's Income is lower than 50k.

# %%
sns.pairplot(ci)

# %% [markdown]
# Observation;
#
# Skewness is present is Census Income Datset.

# %% [markdown]
# # Checking The Skewness

# %%
ci.skew().sort_values(ascending=False)
# Out:
# Capital_gain      11.953690
# Capital_loss       4.594549
# Fnlwgt             1.446972
# Age                0.558738
# Hours_per_week     0.227636
# Education_num     -0.311630
# dtype: float64

# %% [markdown]
# High Skewness is present in Datset.

# %%
sns.distplot(ci["Capital_gain"])
# Out:
# <AxesSubplot:xlabel='Capital_gain', ylabel='Density'>

# %% [markdown]
# Skewness is present in Capital_gain.

# %%
sns.distplot(ci["Capital_loss"])
# Out:
# <AxesSubplot:xlabel='Capital_loss', ylabel='Density'>

# %% [markdown]
# Skewness is present in Capital_loss.

# %%
sns.distplot(ci["Fnlwgt"])
# Out:
# <AxesSubplot:xlabel='Fnlwgt', ylabel='Density'>

# %% [markdown]
# skewness is presnet in Fnlwgt.

# %%
sns.distplot(ci["Age"])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %% [markdown]
# Skewness is present in Age.

# %%
sns.distplot(ci["Hours_per_week"])
# Out:
# <AxesSubplot:xlabel='Hours_per_week', ylabel='Density'>

# %% [markdown]
# Skewness is not present in Hours_per_week.

# %%
sns.distplot(ci["Education_num"])
# Out:
# <AxesSubplot:xlabel='Education_num', ylabel='Density'>

# %% [markdown]
# Skewness is present in Education_num.

# %% [markdown]
# # LabelEncoding

# %%
from sklearn.preprocessing import LabelEncoder

# %%
ci.sample()
# Out:
#       Age Workclass  Fnlwgt   Education  Education_num       Marital_status  \
# 6004   41   Private  182567   Bachelors             13   Married-civ-spouse
#
#             Occupation Relationship    Race    Sex  Capital_gain  \
# 6004   Exec-managerial      Husband   White   Male             0
#
#       Capital_loss  Hours_per_week Native_country Income
# 6004             0              40              ?   >50K

# %%
le=LabelEncoder()
objects=["Workclass","Education","Marital_status","Occupation","Relationship","Race","Sex","Native_country","Income"]
for i in objects:
    ci[i]=le.fit_transform(ci[i])
    
objects
# Out:
# ['Workclass',
#  'Education',
#  'Marital_status',
#  'Occupation',
#  'Relationship',
#  'Race',
#  'Sex',
#  'Native_country',
#  'Income']

# %%
ci.sample(2)
# Out:
#        Age  Workclass  Fnlwgt  Education  Education_num  Marital_status  \
# 18447   54          4  378747          0              6               5
# 16783   47          4  431245          5              4               2
#
#        Occupation  Relationship  Race  Sex  Capital_gain  Capital_loss  \
# 18447          14             4     2    1             0             0
# 16783           3             0     4    1             0             0
#
#        Hours_per_week  Native_country  Income
# 18447              45              39       1
# 16783              40              39       0

# %% [markdown]
# # Removing The Skewness

# %%
from sklearn.preprocessing import power_transform , PowerTransformer

# %%
ci.head(2)
# Out:
#    Age  Workclass  Fnlwgt  Education  Education_num  Marital_status  \
# 0   50          6   83311          9             13               2
# 1   38          4  215646         11              9               0
#
#    Occupation  Relationship  Race  Sex  Capital_gain  Capital_loss  \
# 0           4             0     4    1             0             0
# 1           6             1     4    1             0             0
#
#    Hours_per_week  Native_country  Income
# 0              13              39       0
# 1              40              39       0

# %%
x=ci.drop("Income",axis=1)

# %%
x.sample()
# Out:
#        Age  Workclass  Fnlwgt  Education  Education_num  Marital_status  \
# 12477   41          7   70884         11              9               2
#
#        Occupation  Relationship  Race  Sex  Capital_gain  Capital_loss  \
# 12477          13             0     4    1             0             0
#
#        Hours_per_week  Native_country
# 12477              40              39

# %%
PowerTransformer()
# Out:
# PowerTransformer()

# %%
new_x=power_transform(x)
print(new_x)
# Out:
# [[ 0.89194656  1.64422286 -1.08988899 ... -0.2212132  -2.22151541
#    0.32907402]
#  [ 0.10271741  0.01186427  0.39874263 ... -0.2212132  -0.03557001
#    0.32907402]
#  [ 1.06438077  0.01186427  0.56254016 ... -0.2212132  -0.03557001
#    0.32907402]
#  ...
#  [ 1.33455599  0.01186427 -0.2197547  ... -0.2212132  -0.03557001
#    0.32907402]
#  [-1.35834147  0.01186427  0.27166793 ... -0.2212132  -1.65499204
#    0.32907402]
#  [ 1.00782289  0.79430139  0.98216482 ... -0.2212132  -0.03557001
#    0.32907402]]

# %%
x=pd.DataFrame(new_x,columns=x.columns).skew().sort_values(ascending=False)
x
# Out:
# Capital_loss      4.299511
# Capital_gain      3.016951
# Hours_per_week    0.229556
# Relationship      0.122917
# Workclass         0.061629
# Education_num     0.023885
# Fnlwgt            0.016914
# Age              -0.013897
# Marital_status   -0.114201
# Occupation       -0.187152
# Education        -0.309431
# Sex              -0.719244
# Race             -2.010817
# Native_country   -2.725467
# dtype: float64

# %% [markdown]
# Skewness is present in some columns.

# %%
sns.distplot(ci["Capital_loss"])
# Out:
# <AxesSubplot:xlabel='Capital_loss', ylabel='Density'>

# %%
ci["Capital_loss"]=np.log(1+ci["Capital_loss"])

# %%
sns.distplot(ci["Capital_loss"])
# Out:
# <AxesSubplot:xlabel='Capital_loss', ylabel='Density'>

# %% [markdown]
# Skewness is not removing for this column.

# %%
sns.distplot(ci["Capital_gain"])
# Out:
# <AxesSubplot:xlabel='Capital_gain', ylabel='Density'>

# %%
ci["Capital_gain"]=np.log(1+ci["Capital_gain"])

# %%
sns.distplot(ci["Capital_gain"])
# Out:
# <AxesSubplot:xlabel='Capital_gain', ylabel='Density'>

# %% [markdown]
# Skewness is not removing for this column.

# %%
sns.distplot(ci["Native_country"])
# Out:
# <AxesSubplot:xlabel='Native_country', ylabel='Density'>

# %%
ci["Native_country"]=np.log(1+ci["Native_country"])

# %%
sns.distplot(ci["Native_country"])
# Out:
# <AxesSubplot:xlabel='Native_country', ylabel='Density'>

# %% [markdown]
# Skewness is not removing for Native_country column.

# %% [markdown]
# # Checking The Outliers

# %%
ci.plot(kind="box",subplots=True,layout=(4,4))
# Out:
# Age                   AxesSubplot(0.125,0.71587;0.168478x0.16413)
# Workclass          AxesSubplot(0.327174,0.71587;0.168478x0.16413)
# Fnlwgt             AxesSubplot(0.529348,0.71587;0.168478x0.16413)
# Education          AxesSubplot(0.731522,0.71587;0.168478x0.16413)
# Education_num        AxesSubplot(0.125,0.518913;0.168478x0.16413)
# Marital_status    AxesSubplot(0.327174,0.518913;0.168478x0.16413)
# Occupation        AxesSubplot(0.529348,0.518913;0.168478x0.16413)
# Relationship      AxesSubplot(0.731522,0.518913;0.168478x0.16413)
# Race                 AxesSubplot(0.125,0.321957;0.168478x0.16413)
# Sex               AxesSubplot(0.327174,0.321957;0.168478x0.16413)
# Capital_gain      AxesSubplot(0.529348,0.321957;0.168478x0.16413)
# Capital_loss      AxesSubplot(0.731522,0.321957;0.168478x0.16413)
# Hours_per_week          AxesSubplot(0.125,0.125;0.168478x0.16413)
# Native_country       AxesSubplot(0.327174,0.125;0.168478x0.16413)
# ...

# %% [markdown]
# Outliers are present in census Income dataset.

# %% [markdown]
# # Removing The OUtlires

# %%
from scipy.stats import zscore

# %%
new_ci=np.array(ci)

# %%
new_ci
# Out:
# array([[5.00000000e+01, 6.00000000e+00, 8.33110000e+04, ...,
#         1.30000000e+01, 3.68887945e+00, 0.00000000e+00],
#        [3.80000000e+01, 4.00000000e+00, 2.15646000e+05, ...,
#         4.00000000e+01, 3.68887945e+00, 0.00000000e+00],
#        [5.30000000e+01, 4.00000000e+00, 2.34721000e+05, ...,
#         4.00000000e+01, 3.68887945e+00, 0.00000000e+00],
#        ...,
#        [5.80000000e+01, 4.00000000e+00, 1.51910000e+05, ...,
#         4.00000000e+01, 3.68887945e+00, 0.00000000e+00],
#        [2.20000000e+01, 4.00000000e+00, 2.01490000e+05, ...,
#         2.00000000e+01, 3.68887945e+00, 0.00000000e+00],
#        [5.20000000e+01, 5.00000000e+00, 2.87927000e+05, ...,
#         4.00000000e+01, 3.68887945e+00, 1.00000000e+00]])

# %%
z=np.abs(zscore(ci))
z
# Out:
#             Age  Workclass    Fnlwgt  Education  Education_num  \
# 0      0.837097   1.463883  1.008742   0.335443       1.134779
# 1      0.042640   0.090121  0.245046   0.181319       0.420027
# 2      1.057031   0.090121  0.425770   2.402489       1.197429
# 3      0.775755   0.090121  1.408146   0.335443       1.134779
# 4      0.115952   0.090121  0.898170   0.439700       1.523480
# ...         ...        ...       ...        ...            ...
# 32555  0.849066   0.090121  0.639710   0.852204       0.746077
# 32556  0.103982   0.090121  0.335466   0.181319       0.420027
# 32557  1.423589   0.090121  0.358811   0.181319       0.420027
# 32558  1.215624   0.090121  0.110927   0.181319       0.420027
# 32559  0.983720   0.777002  0.929862   0.181319       0.420027
#
#        Marital_status  Occupation  Relationship      Race       Sex  \
# 0            0.406183    0.608434      0.900177  0.393675  0.703087
# 1            1.734026    0.135480      0.277810  0.393675  0.703087
# ...

# %%
thereshold=3
print(np.where(z>3))
# Out:
# (array([    3,     7,     8, ..., 32550, 32552, 32559], dtype=int64), array([13, 10, 10, ...,  8,  8, 10], dtype=int64))

# %%
new_ci=ci[(z<3).all(axis=1)]
new_ci
# Out:
#        Age  Workclass  Fnlwgt  Education  Education_num  Marital_status  \
# 0       50          6   83311          9             13               2
# 1       38          4  215646         11              9               0
# 2       53          4  234721          1              7               2
# 4       37          4  284582         12             14               2
# 5       49          4  160187          6              5               3
# ...    ...        ...     ...        ...            ...             ...
# 32554   22          4  310152         15             10               4
# 32555   27          4  257302          7             12               2
# 32556   40          4  154374         11              9               2
# 32557   58          4  151910         11              9               6
# 32558   22          4  201490         11              9               4
#
#        Occupation  Relationship  Race  Sex  Capital_gain  Capital_loss  \
# ...

# %%
new_ci.head(2)
# Out:
#    Age  Workclass  Fnlwgt  Education  Education_num  Marital_status  \
# 0   50          6   83311          9             13               2
# 1   38          4  215646         11              9               0
#
#    Occupation  Relationship  Race  Sex  Capital_gain  Capital_loss  \
# 0           4             0     4    1           0.0           0.0
# 1           6             1     4    1           0.0           0.0
#
#    Hours_per_week  Native_country  Income
# 0              13        3.688879       0
# 1              40        3.688879       0

# %%
new_ci.shape
# Out:
# (26132, 15)

# %%
ci.shape
# Out:
# (32560, 15)

# %% [markdown]
# 6428 rows has been removed,it means outliers has been removed.

# %%
ci=new_ci
ci.head()
# Out:
#    Age  Workclass  Fnlwgt  Education  Education_num  Marital_status  \
# 0   50          6   83311          9             13               2
# 1   38          4  215646         11              9               0
# 2   53          4  234721          1              7               2
# 4   37          4  284582         12             14               2
# 5   49          4  160187          6              5               3
#
#    Occupation  Relationship  Race  Sex  Capital_gain  Capital_loss  \
# 0           4             0     4    1           0.0           0.0
# 1           6             1     4    1           0.0           0.0
# 2           6             0     2    1           0.0           0.0
# 4           4             5     4    0           0.0           0.0
# 5           8             1     2    0           0.0           0.0
#
#    Hours_per_week  Native_country  Income
# 0              13        3.688879       0
# 1              40        3.688879       0
# ...

# %%
x=ci.iloc[:,0:-1]
x
# Out:
#        Age  Workclass  Fnlwgt  Education  Education_num  Marital_status  \
# 0       50          6   83311          9             13               2
# 1       38          4  215646         11              9               0
# 2       53          4  234721          1              7               2
# 4       37          4  284582         12             14               2
# 5       49          4  160187          6              5               3
# ...    ...        ...     ...        ...            ...             ...
# 32554   22          4  310152         15             10               4
# 32555   27          4  257302          7             12               2
# 32556   40          4  154374         11              9               2
# 32557   58          4  151910         11              9               6
# 32558   22          4  201490         11              9               4
#
#        Occupation  Relationship  Race  Sex  Capital_gain  Capital_loss  \
# ...

# %% [markdown]
# # MULTICOLLINEARITY

# %%
from scipy import stats
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
def vif(x):
    vif=pd.DataFrame()
    vif["variables"]=x.columns
    vif["VIF FACTOR"]=[variance_inflation_factor(x.values,i) for i in range(x.shape[1])]
    return(vif)

# %%
vif(x)
# Out:
#          variables  VIF FACTOR
# 0              Age   10.029288
# 1        Workclass    8.797811
# 2           Fnlwgt    4.794767
# 3        Education    9.123762
# 4    Education_num   21.925374
# 5   Marital_status    4.371010
# 6       Occupation    3.667444
# 7     Relationship    2.987706
# 8             Race   37.851478
# 9              Sex    4.347708
# 10    Capital_gain    1.025016
# 11    Capital_loss    1.000584
# 12  Hours_per_week   15.012127
# 13  Native_country   87.556573

# %% [markdown]
# NO High Multicollinearty in Dataset.

# %% [markdown]
# # Scaling The data

# %%
from sklearn.preprocessing import StandardScaler

# %%
scale=StandardScaler()
x=scale.fit_transform(x)
x
# Out:
# array([[ 0.91403755,  1.48023756, -1.08653831, ..., -0.00618617,
#         -2.38125715,  0.20333845],
#        [ 0.01950891,  0.09732068,  0.30703079, ..., -0.00618617,
#          0.03103038,  0.20333845],
#        [ 1.13766971,  0.09732068,  0.5079023 , ..., -0.00618617,
#          0.03103038,  0.20333845],
#        ...,
#        [ 0.16859701,  0.09732068, -0.33820113, ..., -0.00618617,
#          0.03103038,  0.20333845],
#        [ 1.51038997,  0.09732068, -0.36414857, ..., -0.00618617,
#          0.03103038,  0.20333845],
#        [-1.17319594,  0.09732068,  0.15795939, ..., -0.00618617,
#         -1.75584927,  0.20333845]])

# %% [markdown]
# Dataset has been scaled.

# %% [markdown]
# # Prediction

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC

# %%
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix

# %%
ci.tail()
# Out:
#        Age  Workclass  Fnlwgt  Education  Education_num  Marital_status  \
# 32554   22          4  310152         15             10               4
# 32555   27          4  257302          7             12               2
# 32556   40          4  154374         11              9               2
# 32557   58          4  151910         11              9               6
# 32558   22          4  201490         11              9               4
#
#        Occupation  Relationship  Race  Sex  Capital_gain  Capital_loss  \
# 32554          11             1     4    1           0.0           0.0
# 32555          13             5     4    0           0.0           0.0
# 32556           7             0     4    1           0.0           0.0
# 32557           1             4     4    0           0.0           0.0
# 32558           1             3     4    1           0.0           0.0
#
#        Hours_per_week  Native_country  Income
# 32554              40        3.688879       0
# ...

# %%
x=ci.drop("Income",axis=1)

# %%
x.sample()
# Out:
#        Age  Workclass  Fnlwgt  Education  Education_num  Marital_status  \
# 22786   55          1   31965         15             10               2
#
#        Occupation  Relationship  Race  Sex  Capital_gain  Capital_loss  \
# 22786           1             0     4    1           0.0           0.0
#
#        Hours_per_week  Native_country
# 22786              40        3.688879

# %%
y=ci["Income"]

# %%
y.sample()
# Out:
# 17659    0
# Name: Income, dtype: int32

# %% [raw]
# spliting the train and test data

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=40)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (18292, 14)
# (7840, 14)
# (18292,)
# (7840,)

# %% [raw]
# GaussianProcessClassifier

# %%
gp=GaussianProcessClassifier()
gp.fit(x_train,y_train)
gppred=gp.predict(x_test)
print(accuracy_score(y_test,gppred)*100)
print(classification_report(y_test,gppred))
print(confusion_matrix(y_test,gppred))
# Out:
# 73.22704081632652
#               precision    recall  f1-score   support
#
#            0       0.84      0.83      0.83      6359
#            1       0.30      0.30      0.30      1481
#
#     accuracy                           0.73      7840
#    macro avg       0.57      0.57      0.57      7840
# weighted avg       0.73      0.73      0.73      7840
#
# [[5295 1064]
#  [1035  446]]

# %% [raw]
# RandomForestClassifier

# %%
rfc=RandomForestClassifier()
rfc.fit(x_train,y_train)
rfcpred=rfc.predict(x_test)
print(accuracy_score(y_test,rfcpred)*100)
print(classification_report(y_test,rfcpred))
print(confusion_matrix(y_test,rfcpred))
# Out:
# 84.2984693877551
#               precision    recall  f1-score   support
#
#            0       0.89      0.92      0.91      6359
#            1       0.60      0.50      0.55      1481
#
#     accuracy                           0.84      7840
#    macro avg       0.74      0.71      0.73      7840
# weighted avg       0.83      0.84      0.84      7840
#
# [[5871  488]
#  [ 743  738]]

# %% [raw]
# DecisionTreeClassifier

# %%
dtc=DecisionTreeClassifier()
dtc.fit(x_train,y_train)
dtcpred=dtc.predict(x_test)
print(accuracy_score(y_test,dtcpred)*100)
print(classification_report(y_test,dtcpred))
print(confusion_matrix(y_test,dtcpred))
# Out:
# 79.5280612244898
#               precision    recall  f1-score   support
#
#            0       0.88      0.87      0.87      6359
#            1       0.46      0.49      0.48      1481
#
#     accuracy                           0.80      7840
#    macro avg       0.67      0.68      0.67      7840
# weighted avg       0.80      0.80      0.80      7840
#
# [[5505  854]
#  [ 751  730]]

# %% [raw]
# KNeighborsClassifier

# %%
knc=KNeighborsClassifier()
knc.fit(x_train,y_train)
kncpred=knc.predict(x_test)
print(accuracy_score(y_test,kncpred)*100)
print(classification_report(y_test,kncpred))
print(confusion_matrix(y_test,kncpred))
# Out:
# 77.62755102040816
#               precision    recall  f1-score   support
#
#            0       0.82      0.93      0.87      6359
#            1       0.28      0.12      0.17      1481
#
#     accuracy                           0.78      7840
#    macro avg       0.55      0.52      0.52      7840
# weighted avg       0.72      0.78      0.74      7840
#
# [[5907  452]
#  [1302  179]]

# %% [raw]
# SVC

# %%
svc=SVC()
svc.fit(x_train,y_train)
svcpred=svc.predict(x_test)
print(accuracy_score(y_test,svcpred)*100)
print(classification_report(y_test,svcpred))
print(confusion_matrix(y_test,svcpred))
# Out:
# 81.10969387755102
#               precision    recall  f1-score   support
#
#            0       0.81      1.00      0.90      6359
#            1       0.00      0.00      0.00      1481
#
#     accuracy                           0.81      7840
#    macro avg       0.41      0.50      0.45      7840
# weighted avg       0.66      0.81      0.73      7840
#
# [[6359    0]
#  [1481    0]]

# %% [markdown]
# RandomForestClassifier and SVC are working well.

# %% [markdown]
# # CROSS VAL SCORE

# %%
from sklearn.model_selection import cross_val_score

# %% [raw]
# GaussianProcessClassifier

# %%
score=cross_val_score(gp,x,y,cv=5)
print(score)
print(score.mean())
print(score.std())
# Out:
# [nan nan nan nan nan]
# nan
# nan

# %% [raw]
# RandomForestClassifier

# %%
score=cross_val_score(rfc,x,y,cv=5)
print(score)
print(score.mean())
print(score.std())
# Out:
# [0.84656591 0.84446145 0.84519709 0.85246843 0.84921546]
# 0.8475816675331822
# 0.0029326925492796706

# %% [raw]
# DecisionTreeClassifier

# %%
score=cross_val_score(dtc,x,y,cv=5)
print(score)
print(score.mean())
print(score.std())
# Out:
# [0.80026784 0.80007653 0.81094527 0.80730961 0.79946422]
# 0.8036126925233145
# 0.004654809840248232

# %% [raw]
# KNeighborsClassifier

# %%
score=cross_val_score(knc,x,y,cv=5)
print(score)
print(score.mean())
print(score.std())
# Out:
# [0.78515401 0.78113641 0.78319939 0.77669346 0.78032912]
# 0.7813024764479467
# 0.0028513377174711834

# %% [raw]
# SVC

# %%
score=cross_val_score(svc,x,y,cv=5)
print(score)
print(score.mean())
print(score.std())
# Out:
# [0.80964224 0.80945093 0.80960582 0.80960582 0.80960582]
# 0.8095821242567901
# 6.709799740218871e-05

# %% [markdown]
# # Hyper Parameter Tuning

# %%
from sklearn.model_selection import GridSearchCV

# %% [raw]
# RandomForestClassifier

# %%
p1={"n_estimators":[100,200,300],"criterion":["gini","entropy","log_loss"],"class_weight":["balanced","balanced_subsample",None],"max_samples":[None,1,2.1,2.0]}

# %%
gd=GridSearchCV(estimator=rfc,param_grid=p1,cv=5)
gd.fit(x,y)
print(gd.best_params_)
print(gd.best_score_)
# Out:
# {'class_weight': 'balanced_subsample', 'criterion': 'entropy', 'max_samples': None, 'n_estimators': 200}
# 0.8487296194045593

# %%
rfc=RandomForestClassifier(class_weight="balanced_subsample",criterion="entropy",max_samples=None,n_estimators=200)
rfc.fit(x_train,y_train)
rfcpred=rfc.predict(x_test)
print(accuracy_score(y_test,rfcpred)*100)
print(classification_report(y_test,rfcpred))
print(confusion_matrix(y_test,rfcpred))
# Out:
# 84.40051020408164
#               precision    recall  f1-score   support
#
#            0       0.89      0.93      0.91      6359
#            1       0.61      0.50      0.55      1481
#
#     accuracy                           0.84      7840
#    macro avg       0.75      0.71      0.73      7840
# weighted avg       0.83      0.84      0.84      7840
#
# [[5883  476]
#  [ 747  734]]

# %% [raw]
# DecisionTreeClassifier

# %%
p3={"criterion":["gini","entropy","log_loss"],"splitter":["best","random"],"min_impurity_decrease":[0.0,0.1,0.3],"max_leaf_nodes":[None,1,2,3]}

# %%
gd=GridSearchCV(estimator=dtc,param_grid=p3,cv=5)
gd.fit(x,y)
print(gd.best_params_)
print(gd.best_score_)
# Out:
# {'criterion': 'gini', 'max_leaf_nodes': 3, 'min_impurity_decrease': 0.0, 'splitter': 'best'}
# 0.8407701232765694

# %%
dtc=DecisionTreeClassifier(criterion="gini",max_leaf_nodes=3,min_impurity_decrease=0.0,splitter="best")
dtc.fit(x_train,y_train)
dtcpred=dtc.predict(x_test)
print(accuracy_score(y_test,dtcpred)*100)
print(classification_report(y_test,dtcpred))
print(confusion_matrix(y_test,dtcpred))
# Out:
# 84.375
#               precision    recall  f1-score   support
#
#            0       0.86      0.96      0.91      6359
#            1       0.66      0.35      0.46      1481
#
#     accuracy                           0.84      7840
#    macro avg       0.76      0.66      0.68      7840
# weighted avg       0.83      0.84      0.82      7840
#
# [[6093  266]
#  [ 959  522]]

# %% [raw]
# KNeighborsClassifier

# %%
p4={"n_jobs":[None,1,2,3],"p":[2,4,6],"leaf_size":[30,40,50],"algorithm":["auto","ball_tree","kd_tree","brute"],"weights":["uniform","distance"]}

# %% [raw]
# getting erro in KNeighborsClassifier.

# %% [raw]
# SVC

# %%
p5={"break_ties":[True,False],"decision_function_shape":["ovo","ovr"],"max_iter":[1,2,3,4],"verbose":[False,True]}

# %%
gd=GridSearchCV(estimator=svc,param_grid=p5,cv=5)
gd.fit(x,y)
print(gd.best_params_)
print(gd.best_score_)
# Out:
# [LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM]{'break_ties': True, 'decision_function_shape': 'ovr', 'max_iter': 2, 'verbose': False}
# 0.570646897958589

# %%
svc=SVC(break_ties=True,decision_function_shape="ovr",max_iter=2,verbose=False)
svc.fit(x_train,y_train)
svcpred=svc.predict(x_test)
print(accuracy_score(y_test,svcpred)*100)
print(classification_report(y_test,svcpred))
print(confusion_matrix(y_test,svcpred))
# Out:
# 31.288265306122447
#               precision    recall  f1-score   support
#
#            0       0.83      0.19      0.31      6359
#            1       0.19      0.83      0.31      1481
#
#     accuracy                           0.31      7840
#    macro avg       0.51      0.51      0.31      7840
# weighted avg       0.71      0.31      0.31      7840
#
# [[1221 5138]
#  [ 249 1232]]

# %% [markdown]
# Observation;
#
# DecisionTreeClassifier and RandomForestClassifier is working well.

# %% [markdown]
# # Saving the best model

# %%
import pickle

file="census_income_prediction"
pickle.dump(rfc,open(file,"wb"))

# %% [markdown]
# # Loading the file

# %%
load_model=pickle.load(open(file,"rb"))
load_model.predict(x_test)
# Out:
# array([0, 1, 0, ..., 0, 0, 0])
