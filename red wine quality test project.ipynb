# %% [markdown]
# # Loading the Modules

# %%
#LOADING THE RELATED MODULES


import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings 
warnings.filterwarnings('ignore')

# %% [markdown]
# # Loading the dataset

# %%
#LOADING THE DATASET

data=pd.read_csv("winequality-red.csv")

# %%
data
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
# pd.set_option('display.max_rows',None) this code display all the rows

pd.set_option('display.max_rows',10)

# %%
data
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
data.keys()
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
data.values
# Out:
# array([[ 7.4  ,  0.7  ,  0.   , ...,  0.56 ,  9.4  ,  5.   ],
#        [ 7.8  ,  0.88 ,  0.   , ...,  0.68 ,  9.8  ,  5.   ],
#        [ 7.8  ,  0.76 ,  0.04 , ...,  0.65 ,  9.8  ,  5.   ],
#        ...,
#        [ 6.3  ,  0.51 ,  0.13 , ...,  0.75 , 11.   ,  6.   ],
#        [ 5.9  ,  0.645,  0.12 , ...,  0.71 , 10.2  ,  5.   ],
#        [ 6.   ,  0.31 ,  0.47 , ...,  0.66 , 11.   ,  6.   ]])

# %%
data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
data.tail()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 1594     10.5        5
# ...

# %%
data.sample(5)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 830             7.5             0.685         0.07             2.5      0.058
# 1366            7.3             0.740         0.08             1.7      0.094
# 1029            7.7             0.580         0.01             1.8      0.088
# 403            11.4             0.600         0.49             2.7      0.085
# 1203            9.9             0.740         0.19             5.8      0.111
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 830                   5.0                   9.0  0.99632  3.38       0.55
# 1366                 10.0                  45.0  0.99576  3.24       0.50
# 1029                 12.0                  18.0  0.99568  3.32       0.56
# 403                  10.0                  41.0  0.99940  3.15       0.63
# 1203                 33.0                  76.0  0.99878  3.14       0.55
#
#       alcohol  quality
# 830      10.9        4
# ...

# %%
data.shape
# Out:
# (1599, 12)

# %% [markdown]
# Observation:
#
# data has 1600 rows and 12 columns.

# %%
data.dtypes
# Out:
# fixed acidity       float64
# volatile acidity    float64
# citric acid         float64
# residual sugar      float64
# chlorides           float64
#                      ...
# density             float64
# pH                  float64
# sulphates           float64
# alcohol             float64
# quality               int64
# Length: 12, dtype: object

# %% [markdown]
# Observation:
#
# data has only two types float and int.

# %%
data.isnull().sum()
# Out:
# fixed acidity       0
# volatile acidity    0
# citric acid         0
# residual sugar      0
# chlorides           0
#                    ..
# density             0
# pH                  0
# sulphates           0
# alcohol             0
# quality             0
# Length: 12, dtype: int64

# %% [markdown]
# Observation:
#     There is no null values in data.

# %% [markdown]
# # EDA

# %%
sns.heatmap(data.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# Observation:
#
#     No blanks in heatmap it means there is no null values in data.

# %%
data["quality"].value_counts()
# Out:
# 5    681
# 6    638
# 7    199
# 4     53
# 8     18
# 3     10
# Name: quality, dtype: int64

# %% [markdown]
# Observation:
# There is 6 types of ranking in wine quality.
# 5 and 6 rating of quality is 681 and 638 which is highest rating,and 8 and 3 rating of quality is only 18 and 10 which is lowest.

# %%
sns.countplot(x="quality",data=data)
# Out:
# <AxesSubplot:xlabel='quality', ylabel='count'>

# %% [markdown]
# Observation:
#
# 5 and 6 quality rating are highest. and 8,4 and 3 quality rating are lowest.

# %%
sns.histplot(x="quality",data=data)
# Out:
# <AxesSubplot:xlabel='quality', ylabel='Count'>

# %% [markdown]
# Observation:
#
# frequency of 5 and 6 quality is highest in the data.

# %%
data["fixed acidity"].value_counts()
# Out:
# 7.2     67
# 7.1     57
# 7.8     53
# 7.5     52
# 7.0     50
#         ..
# 13.5     1
# 13.8     1
# 13.4     1
# 4.7      1
# 5.5      1
# Name: fixed acidity, Length: 96, dtype: int64

# %% [markdown]
# Observation:
#
# fixed acidity is highest between 7.0 to 7.8

# %%
data["fixed acidity"].unique()
# Out:
# array([ 7.4,  7.8, 11.2,  7.9,  7.3,  7.5,  6.7,  5.6,  8.9,  8.5,  8.1,
#         7.6,  6.9,  6.3,  7.1,  8.3,  5.2,  5.7,  8.8,  6.8,  4.6,  7.7,
#         8.7,  6.4,  6.6,  8.6, 10.2,  7. ,  7.2,  9.3,  8. ,  9.7,  6.2,
#         5. ,  4.7,  8.4, 10.1,  9.4,  9. ,  8.2,  6.1,  5.8,  9.2, 11.5,
#         5.4,  9.6, 12.8, 11. , 11.6, 12. , 15. , 10.8, 11.1, 10. , 12.5,
#        11.8, 10.9, 10.3, 11.4,  9.9, 10.4, 13.3, 10.6,  9.8, 13.4, 10.7,
#        11.9, 12.4, 12.2, 13.8,  9.1, 13.5, 10.5, 12.6, 14. , 13.7,  9.5,
#        12.7, 12.3, 15.6,  5.3, 11.3, 13. ,  6.5, 12.9, 14.3, 15.5, 11.7,
#        13.2, 15.9, 12.1,  5.1,  4.9,  5.9,  6. ,  5.5])

# %% [markdown]
# Observation:
#
# Values of fixed acidity is higer in between 7.0 to 7.8.

# %%
sns.histplot(data=data,x="fixed acidity",y="quality")
# Out:
# <AxesSubplot:xlabel='fixed acidity', ylabel='quality'>

# %% [markdown]
# Observation:
#
# quality is higher in between 7 to 13 fixed acidity.

# %%
sns.lineplot(x='fixed acidity',y="quality",data=data)
# Out:
# <AxesSubplot:xlabel='fixed acidity', ylabel='quality'>

# %%
sns.scatterplot(x='fixed acidity',y="quality",data=data)
# Out:
# <AxesSubplot:xlabel='fixed acidity', ylabel='quality'>

# %%
data["volatile acidity"].value_counts()
# Out:
# 0.600    47
# 0.500    46
# 0.430    43
# 0.590    39
# 0.360    38
#          ..
# 1.035     1
# 0.565     1
# 1.130     1
# 1.115     1
# 1.090     1
# Name: volatile acidity, Length: 143, dtype: int64

# %% [markdown]
# Observation:
#
# volatile acidity is higher between 0.360 to 0.600

# %%
sns.histplot("volatile acidity")
# Out:
# <AxesSubplot:ylabel='Count'>

# %% [markdown]
# Observation:
#
# volatile acidity values are between 0.0 to 1.0

# %%
data["volatile acidity"].unique()
# Out:
# array([0.7  , 0.88 , 0.76 , 0.28 , 0.66 , 0.6  , 0.65 , 0.58 , 0.5  ,
#        0.615, 0.61 , 0.62 , 0.56 , 0.59 , 0.32 , 0.22 , 0.39 , 0.43 ,
#        0.49 , 0.4  , 0.41 , 0.71 , 0.645, 0.675, 0.685, 0.655, 0.605,
#        0.38 , 1.13 , 0.45 , 0.67 , 0.52 , 0.935, 0.29 , 0.31 , 0.51 ,
#        0.42 , 0.63 , 0.69 , 0.735, 0.725, 0.705, 0.785, 0.75 , 0.625,
#        0.3  , 0.55 , 1.02 , 0.775, 0.9  , 0.545, 0.575, 0.33 , 0.54 ,
#        1.07 , 0.695, 1.33 , 0.745, 1.04 , 0.715, 0.415, 0.34 , 0.68 ,
#        0.95 , 0.53 , 0.64 , 0.885, 0.805, 0.73 , 0.37 , 0.835, 1.09 ,
#        0.57 , 0.44 , 0.635, 0.82 , 0.48 , 1.   , 0.21 , 0.35 , 0.975,
#        0.26 , 0.87 , 0.18 , 0.27 , 0.2  , 0.36 , 0.83 , 0.46 , 0.47 ,
#        0.77 , 0.815, 0.795, 0.665, 0.765, 0.24 , 0.85 , 0.84 , 0.96 ,
#        0.78 , 0.23 , 0.315, 0.365, 0.25 , 0.825, 0.72 , 0.595, 0.585,
#        0.915, 0.755, 0.845, 1.24 , 0.8  , 0.98 , 1.185, 0.92 , 1.035,
# ...

# %%
sns.scatterplot(data=data,x="volatile acidity",y="quality")
# Out:
# <AxesSubplot:xlabel='volatile acidity', ylabel='quality'>

# %% [markdown]
# Observation:
#
# quality are higher in between 0.2 to 1.1 volatile acidity.

# %%
data["citric acid"].value_counts()
# Out:
# 0.00    132
# 0.49     68
# 0.24     51
# 0.02     50
# 0.26     38
#        ...
# 0.72      1
# 0.62      1
# 0.75      1
# 1.00      1
# 0.78      1
# Name: citric acid, Length: 80, dtype: int64

# %% [markdown]
# Observation:
#
# citric acid higher value is 0.00.

# %%
data['citric acid'].unique()
# Out:
# array([0.  , 0.04, 0.56, 0.06, 0.02, 0.36, 0.08, 0.29, 0.18, 0.19, 0.28,
#        0.51, 0.48, 0.31, 0.21, 0.11, 0.14, 0.16, 0.24, 0.07, 0.12, 0.25,
#        0.09, 0.3 , 0.2 , 0.22, 0.15, 0.43, 0.52, 0.23, 0.37, 0.26, 0.57,
#        0.4 , 0.49, 0.05, 0.54, 0.64, 0.7 , 0.47, 0.44, 0.17, 0.68, 0.53,
#        0.1 , 0.01, 0.55, 1.  , 0.03, 0.42, 0.33, 0.32, 0.35, 0.6 , 0.74,
#        0.58, 0.5 , 0.76, 0.46, 0.45, 0.38, 0.39, 0.66, 0.62, 0.67, 0.79,
#        0.63, 0.61, 0.71, 0.65, 0.59, 0.34, 0.69, 0.73, 0.72, 0.41, 0.27,
#        0.75, 0.13, 0.78])

# %%
sns.scatterplot(data=data,x="quality",y="citric acid")
# Out:
# <AxesSubplot:xlabel='quality', ylabel='citric acid'>

# %% [markdown]
# Observation:
#
# quality is higher in between 0.0 to 0.7 citric acid.

# %%
data["residual sugar"].value_counts()
# Out:
# 2.00     156
# 2.20     131
# 1.80     129
# 2.10     128
# 1.90     117
#         ...
# 4.25       1
# 2.85       1
# 3.45       1
# 2.35       1
# 13.90      1
# Name: residual sugar, Length: 91, dtype: int64

# %% [markdown]
# Observation:
#
# residual sugar values are higher between 1.90 to 2.00

# %%
data["residual sugar"].unique()
# Out:
# array([ 1.9 ,  2.6 ,  2.3 ,  1.8 ,  1.6 ,  1.2 ,  2.  ,  6.1 ,  3.8 ,
#         3.9 ,  1.7 ,  4.4 ,  2.4 ,  1.4 ,  2.5 , 10.7 ,  5.5 ,  2.1 ,
#         1.5 ,  5.9 ,  2.8 ,  2.2 ,  3.  ,  3.4 ,  5.1 ,  4.65,  1.3 ,
#         7.3 ,  7.2 ,  2.9 ,  2.7 ,  5.6 ,  3.1 ,  3.2 ,  3.3 ,  3.6 ,
#         4.  ,  7.  ,  6.4 ,  3.5 , 11.  ,  3.65,  4.5 ,  4.8 ,  2.95,
#         5.8 ,  6.2 ,  4.2 ,  7.9 ,  3.7 ,  6.7 ,  6.6 ,  2.15,  5.2 ,
#         2.55, 15.5 ,  4.1 ,  8.3 ,  6.55,  4.6 ,  4.3 ,  5.15,  6.3 ,
#         6.  ,  8.6 ,  7.5 ,  2.25,  4.25,  2.85,  3.45,  2.35,  2.65,
#         9.  ,  8.8 ,  5.  ,  1.65,  2.05,  0.9 ,  8.9 ,  8.1 ,  4.7 ,
#         1.75,  7.8 , 12.9 , 13.4 ,  5.4 , 15.4 ,  3.75, 13.8 ,  5.7 ,
#        13.9 ])

# %%
sns.scatterplot(data=data,x="quality",y="residual sugar")
# Out:
# <AxesSubplot:xlabel='quality', ylabel='residual sugar'>

# %% [markdown]
# Observation:
#
# quality are higher between 1.0 to 8 residual sugar.

# %%
data.head(2)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70          0.0             1.9      0.076
# 1            7.8              0.88          0.0             2.6      0.098
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5

# %%
data["chlorides"].value_counts()
# Out:
# 0.080    66
# 0.074    55
# 0.076    51
# 0.078    51
# 0.084    49
#          ..
# 0.108     1
# 0.148     1
# 0.143     1
# 0.222     1
# 0.230     1
# Name: chlorides, Length: 153, dtype: int64

# %% [markdown]
# Observation:
#
# chlorides values is higher between 0.074 to 0.084.

# %%
data["chlorides"].unique()
# Out:
# array([0.076, 0.098, 0.092, 0.075, 0.069, 0.065, 0.073, 0.071, 0.097,
#        0.089, 0.114, 0.176, 0.17 , 0.368, 0.086, 0.341, 0.077, 0.082,
#        0.106, 0.084, 0.085, 0.08 , 0.105, 0.083, 0.103, 0.066, 0.172,
#        0.074, 0.088, 0.332, 0.05 , 0.054, 0.113, 0.068, 0.081, 0.11 ,
#        0.07 , 0.111, 0.079, 0.115, 0.094, 0.093, 0.104, 0.464, 0.401,
#        0.062, 0.107, 0.045, 0.058, 0.102, 0.467, 0.091, 0.122, 0.09 ,
#        0.119, 0.178, 0.146, 0.072, 0.118, 0.049, 0.06 , 0.117, 0.087,
#        0.236, 0.61 , 0.095, 0.1  , 0.36 , 0.067, 0.27 , 0.099, 0.046,
#        0.061, 0.056, 0.039, 0.059, 0.101, 0.057, 0.337, 0.078, 0.263,
#        0.063, 0.611, 0.064, 0.096, 0.358, 0.343, 0.186, 0.112, 0.213,
#        0.214, 0.121, 0.128, 0.052, 0.12 , 0.116, 0.109, 0.159, 0.124,
#        0.174, 0.047, 0.127, 0.413, 0.152, 0.053, 0.055, 0.051, 0.125,
#        0.2  , 0.171, 0.226, 0.25 , 0.108, 0.148, 0.143, 0.222, 0.157,
# ...

# %%
sns.scatterplot(x="quality",y="chlorides",data=data)
# Out:
# <AxesSubplot:xlabel='quality', ylabel='chlorides'>

# %% [markdown]
# Observation:
#
# quality are higher between 0.1 to 0.5 chlorides.

# %%
data["free sulfur dioxide"].value_counts()
# Out:
# 6.0     138
# 5.0     104
# 10.0     79
# 15.0     78
# 12.0     75
#        ...
# 2.0       1
# 46.0      1
# 54.0      1
# 40.5      1
# 66.0      1
# Name: free sulfur dioxide, Length: 60, dtype: int64

# %% [markdown]
# Observation:
#
# 5.0 and 6.0 free sulfur dioxide is higher.

# %%
data["free sulfur dioxide"].unique()
# Out:
# array([11. , 25. , 15. , 17. , 13. ,  9. , 16. , 52. , 51. , 35. ,  6. ,
#        29. , 23. , 10. , 21. ,  4. , 14. ,  8. , 22. , 40. ,  5. ,  3. ,
#         7. , 12. , 30. , 33. , 50. , 19. , 20. , 27. , 18. , 28. , 34. ,
#        42. , 41. , 37. , 32. , 36. , 24. , 26. , 39. , 40.5, 68. , 31. ,
#        38. , 43. , 47. ,  1. , 54. , 46. , 45. ,  2. ,  5.5, 53. , 37.5,
#        57. , 48. , 72. , 55. , 66. ])

# %%
sns.scatterplot(x="quality",y="free sulfur dioxide",data=data)
# Out:
# <AxesSubplot:xlabel='quality', ylabel='free sulfur dioxide'>

# %% [markdown]
# Observation:
#
# Quality are higher in between 1 to 52 free sulfur dioxide.

# %%
data["total sulfur dioxide"].value_counts()
# Out:
# 28.0     43
# 24.0     36
# 15.0     35
# 18.0     35
# 23.0     34
#          ..
# 139.0     1
# 149.0     1
# 152.0     1
# 155.0     1
# 165.0     1
# Name: total sulfur dioxide, Length: 144, dtype: int64

# %% [markdown]
# Observation:
#
# total sulfur dioxide values are higher in between 15.0 to 28.0.

# %%
data["total sulfur dioxide"].unique()
# Out:
# array([ 34. ,  67. ,  54. ,  60. ,  40. ,  59. ,  21. ,  18. , 102. ,
#         65. ,  29. , 145. , 148. , 103. ,  56. ,  71. ,  37. ,  23. ,
#         11. ,  35. ,  16. ,  82. , 113. ,  83. ,  50. ,  15. ,  30. ,
#         19. ,  87. ,  46. ,  14. , 114. ,  12. ,  96. , 119. ,  73. ,
#         45. ,  10. , 110. ,  52. , 112. ,  39. ,  27. ,  94. ,  43. ,
#         42. ,  80. ,  51. ,  61. , 136. ,  31. , 125. ,  24. , 140. ,
#        133. ,  85. , 106. ,  22. ,  36. ,  69. ,  64. , 153. ,  47. ,
#        108. , 111. ,  62. ,  28. ,  89. ,  13. ,  90. , 134. ,  99. ,
#         26. ,  63. , 105. ,  20. , 141. ,  88. , 129. , 128. ,  86. ,
#        121. , 101. ,  44. ,   8. ,  49. ,  38. , 143. , 144. , 127. ,
#        126. , 120. ,  55. ,  93. ,  95. ,  41. ,  58. ,  72. ,  81. ,
#        109. ,  33. ,  53. ,  98. ,  48. ,  70. ,  25. , 135. ,  92. ,
#         74. ,  32. ,  77. , 165. ,  75. , 124. ,  78. , 122. ,  66. ,
# ...

# %%
sns.scatterplot(x="total sulfur dioxide",y="quality",data=data)
# Out:
# <AxesSubplot:xlabel='total sulfur dioxide', ylabel='quality'>

# %% [markdown]
# Observation:
#
# Quality are higher in between 10 to 150 total sulfur dioxide.

# %%
sns.catplot(x="quality",y="total sulfur dioxide",kind="bar",data=data)

# %% [markdown]
# Observation:
#
# Quality are normaly distributed in total sulfur dioxide.

# %%
data["density"].value_counts()
# Out:
# 0.99720    36
# 0.99680    35
# 0.99760    35
# 0.99800    29
# 0.99620    28
#            ..
# 0.99684     1
# 0.99764     1
# 0.99473     1
# 0.99320     1
# 0.99651     1
# Name: density, Length: 436, dtype: int64

# %% [markdown]
# Observation:
#
# values of density are almost same.

# %%
data["density"].unique()
# Out:
# array([0.9978 , 0.9968 , 0.997  , 0.998  , 0.9964 , 0.9946 , 0.9959 ,
#        0.9943 , 0.9974 , 0.9986 , 0.9969 , 0.9982 , 0.9966 , 0.9955 ,
#        0.9962 , 0.9972 , 0.9958 , 0.9993 , 0.9957 , 0.9975 , 0.994  ,
#        0.9976 , 0.9934 , 0.9954 , 0.9971 , 0.9956 , 0.9983 , 0.9967 ,
#        0.9961 , 0.9984 , 0.9938 , 0.9932 , 0.9965 , 0.9963 , 0.996  ,
#        0.9973 , 0.9988 , 0.9937 , 0.9952 , 0.9916 , 0.9944 , 0.9996 ,
#        0.995  , 0.9981 , 0.9953 , 0.9924 , 0.9948 , 0.99695, 0.99545,
#        0.99615, 0.9994 , 0.99625, 0.99585, 0.99685, 0.99655, 0.99525,
#        0.99815, 0.99745, 0.9927 , 0.99675, 0.99925, 0.99565, 1.00005,
#        0.9985 , 0.99965, 0.99575, 0.9999 , 1.00025, 0.9987 , 0.99935,
#        0.99735, 0.99915, 0.9991 , 1.00015, 0.9997 , 1.001  , 0.9979 ,
#        1.0014 , 1.0001 , 0.99855, 0.99845, 0.9998 , 0.99645, 0.99865,
#        0.9989 , 0.99975, 0.999  , 1.0015 , 1.0002 , 0.9992 , 1.0008 ,
# ...

# %%
sns.scatterplot(x="quality",y="density",data=data)
# Out:
# <AxesSubplot:xlabel='quality', ylabel='density'>

# %%
sns.catplot(x="quality",y="density",data=data,kind="bar")

# %% [markdown]
# Observation:
#
# All quality rate are same in density.

# %%
data["pH"].value_counts()
# Out:
# 3.30    57
# 3.36    56
# 3.26    53
# 3.38    48
# 3.39    48
#         ..
# 3.75     1
# 2.74     1
# 3.70     1
# 3.85     1
# 2.90     1
# Name: pH, Length: 89, dtype: int64

# %% [markdown]
# Observation:
#
# Value of ph is in between 2.90 to 3.90.

# %%
data['pH'].unique()
# Out:
# array([3.51, 3.2 , 3.26, 3.16, 3.3 , 3.39, 3.36, 3.35, 3.28, 3.58, 3.17,
#        3.11, 3.38, 3.04, 3.52, 3.43, 3.34, 3.47, 3.46, 3.45, 3.4 , 3.42,
#        3.23, 3.5 , 3.33, 3.21, 3.48, 3.9 , 3.25, 3.32, 3.15, 3.41, 3.44,
#        3.31, 3.54, 3.13, 2.93, 3.14, 3.75, 3.85, 3.29, 3.08, 3.37, 3.19,
#        3.07, 3.49, 3.53, 3.24, 3.63, 3.22, 3.68, 2.74, 3.59, 3.  , 3.12,
#        3.57, 3.61, 3.06, 3.6 , 3.69, 3.1 , 3.05, 3.67, 3.27, 3.18, 3.02,
#        3.55, 2.99, 3.01, 3.56, 3.03, 3.62, 2.88, 2.95, 2.98, 3.09, 2.86,
#        3.74, 2.92, 3.72, 2.87, 2.89, 2.94, 3.66, 3.71, 3.78, 3.7 , 4.01,
#        2.9 ])

# %%
sns.scatterplot(x="quality",y="pH",data=data)
# Out:
# <AxesSubplot:xlabel='quality', ylabel='pH'>

# %%
sns.catplot(x="quality",y="pH",kind="bar",data=data)

# %% [markdown]
# Observation:
#
# quality rate is same in ph.

# %%
data["sulphates"].value_counts()
# Out:
# 0.60    69
# 0.58    68
# 0.54    68
# 0.62    61
# 0.56    60
#         ..
# 1.00     1
# 1.59     1
# 0.33     1
# 1.26     1
# 1.01     1
# Name: sulphates, Length: 96, dtype: int64

# %% [markdown]
# Observation:
#
# Value of sulphates is higher in between 0.54 to 0.62.

# %%
data["sulphates"].unique()
# Out:
# array([0.56, 0.68, 0.65, 0.58, 0.46, 0.47, 0.57, 0.8 , 0.54, 0.52, 1.56,
#        0.88, 0.93, 0.75, 1.28, 0.5 , 1.08, 0.53, 0.91, 0.63, 0.59, 0.55,
#        0.66, 0.6 , 0.73, 0.48, 0.83, 0.51, 0.9 , 1.2 , 0.74, 0.64, 0.77,
#        0.71, 0.62, 0.39, 0.79, 0.95, 0.82, 1.12, 1.14, 0.78, 1.95, 1.22,
#        1.98, 0.61, 1.31, 0.69, 0.67, 0.7 , 0.49, 0.92, 2.  , 0.72, 1.59,
#        0.33, 1.02, 0.97, 0.85, 0.43, 1.03, 0.86, 0.76, 1.61, 1.09, 0.84,
#        0.96, 0.45, 1.26, 0.87, 0.81, 1.  , 1.36, 1.18, 0.89, 0.98, 1.13,
#        1.04, 1.11, 0.99, 1.07, 0.44, 1.06, 1.05, 0.42, 1.17, 1.62, 0.94,
#        1.34, 1.16, 1.1 , 0.4 , 1.15, 0.37, 1.33, 1.01])

# %%
sns.scatterplot(x="quality",y="sulphates",data=data)
# Out:
# <AxesSubplot:xlabel='quality', ylabel='sulphates'>

# %% [markdown]
# Observation:
#
# Quality are higher in between 0.30 to 1.30 sulphates.

# %%
data["alcohol"].value_counts()
# Out:
# 9.500000     139
# 9.400000     103
# 9.800000      78
# 9.200000      72
# 10.000000     67
#             ...
# 9.950000       1
# 9.233333       1
# 9.250000       1
# 9.050000       1
# 10.750000      1
# Name: alcohol, Length: 65, dtype: int64

# %% [markdown]
# Observation:
#
# Values of Alcohol are almost same. Higher value of alcohol is 9.500.

# %%
data["alcohol"].unique()
# Out:
# array([ 9.4       ,  9.8       , 10.        ,  9.5       , 10.5       ,
#         9.2       ,  9.9       ,  9.1       ,  9.3       ,  9.        ,
#         9.7       , 10.1       , 10.6       ,  9.6       , 10.8       ,
#        10.3       , 13.1       , 10.2       , 10.9       , 10.7       ,
#        12.9       , 10.4       , 13.        , 14.        , 11.5       ,
#        11.4       , 12.4       , 11.        , 12.2       , 12.8       ,
#        12.6       , 12.5       , 11.7       , 11.3       , 12.3       ,
#        12.        , 11.9       , 11.8       ,  8.7       , 13.3       ,
#        11.2       , 11.6       , 11.1       , 13.4       , 12.1       ,
#         8.4       , 12.7       , 14.9       , 13.2       , 13.6       ,
#        13.5       , 10.03333333,  9.55      ,  8.5       , 11.06666667,
#         9.56666667, 10.55      ,  8.8       , 13.56666667, 11.95      ,
#         9.95      ,  9.23333333,  9.25      ,  9.05      , 10.75      ])

# %%
sns.scatterplot(x="quality",y="alcohol",data=data)
# Out:
# <AxesSubplot:xlabel='quality', ylabel='alcohol'>

# %% [markdown]
# Observation:
#
# Quality of Alcohol is higher in between 8 to 14.

# %%
sns.pairplot(data)

# %% [markdown]
# Observation:
#
# skewness is present in residual sugar,total sulfur dioxide and chlorides

# %% [markdown]
# # SATISTICS SUMMARY

# %%
data.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %% [markdown]
# Observation:
#
# counts are same in red wine data it means no null value in  red wine data.
#
# mean is greater than median it mean total sulfur dioxide is skewed to the right side.

# %%
data.corr().sum()
# Out:
# fixed acidity       1.587537
# volatile acidity   -0.276314
# citric acid         1.913252
# residual sugar      2.036923
# chlorides           1.424218
#                       ...
# density             1.795968
# pH                 -0.727186
# sulphates           2.003032
# alcohol             0.671033
# quality             1.103848
# Length: 12, dtype: float64

# %% [markdown]
# Observation:
#
# volatile acidity and pH is nagitive correlated and residual sugar and sulphates.

# %% [markdown]
# # SKWENESS

# %%
data.sample(2)
# Out:
#      fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 707            7.4              0.49         0.19             3.0      0.077
# 746            8.2              0.34         0.38             2.5      0.080
#
#      free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 707                 16.0                  37.0   0.9966  3.37       0.51
# 746                 12.0                  57.0   0.9978  3.30       0.47
#
#      alcohol  quality
# 707     10.5        5
# 746      9.0        6

# %%
data.skew()
# Out:
# fixed acidity       0.982751
# volatile acidity    0.671593
# citric acid         0.318337
# residual sugar      4.540655
# chlorides           5.680347
#                       ...
# density             0.071288
# pH                  0.193683
# sulphates           2.428672
# alcohol             0.860829
# quality             0.217802
# Length: 12, dtype: float64

# %% [markdown]
# Observation:
#
# residual sugar,chlorides and sulphates are highly skewed.

# %%
sns.distplot(data["fixed acidity"],bins=10)
# Out:
# <AxesSubplot:xlabel='fixed acidity', ylabel='Density'>

# %% [markdown]
# Observation:
#
# skewness is present in fixed scidity.

# %%
sns.distplot(data["volatile acidity"],bins=10)
# Out:
# <AxesSubplot:xlabel='volatile acidity', ylabel='Density'>

# %% [markdown]
# Observation:
#
# skewness is present in volatile acidity.

# %%
sns.distplot(data["citric acid"],bins=10)
# Out:
# <AxesSubplot:xlabel='citric acid', ylabel='Density'>

# %%
sns.distplot(data["residual sugar"],bins=10)
# Out:
# <AxesSubplot:xlabel='residual sugar', ylabel='Density'>

# %% [markdown]
# Observation:
#
# High skewness is present residual sugar.

# %%
sns.distplot(data["chlorides"],bins=10)
# Out:
# <AxesSubplot:xlabel='chlorides', ylabel='Density'>

# %% [markdown]
# Observation:
#
# High skewness is present in chlorides.

# %%
sns.distplot(data["free sulfur dioxide"],bins=10)
# Out:
# <AxesSubplot:xlabel='free sulfur dioxide', ylabel='Density'>

# %% [markdown]
# Observation:
#
# skewness is present in free sulfur dioxide.

# %%
sns.distplot(data["total sulfur dioxide"],bins=10)
# Out:
# <AxesSubplot:xlabel='total sulfur dioxide', ylabel='Density'>

# %% [markdown]
# Observation:
#
# Skewness is present in total sulfur dioxide.

# %%
sns.distplot(data["density"],bins=10)
# Out:
# <AxesSubplot:xlabel='density', ylabel='Density'>

# %% [markdown]
# Observation:
#
# Skewness is not present in density.

# %%
sns.distplot(data["pH"],bins=10)
# Out:
# <AxesSubplot:xlabel='pH', ylabel='Density'>

# %% [markdown]
# Observation:
#
# Skewness is not present in pH.

# %%
sns.distplot(data["sulphates"],bins=10)
# Out:
# <AxesSubplot:xlabel='sulphates', ylabel='Density'>

# %% [markdown]
# Observation:
#
# Skewness is present in sulphates.

# %%
sns.distplot(data["alcohol"],bins=10)
# Out:
# <AxesSubplot:xlabel='alcohol', ylabel='Density'>

# %% [markdown]
# Observation:
#
# Skewness is present in alcohol.

# %%
data.tail(2)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 1597     10.2        5
# 1598     11.0        6

# %% [markdown]
# spliting the data.

# %%
x=data.iloc[:,:-1]
x.head(2)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70          0.0             1.9      0.076
# 1            7.8              0.88          0.0             2.6      0.098
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
#
#    alcohol
# 0      9.4
# 1      9.8

# %%
y=data.iloc[:,-1]
y.sample(2)
# Out:
# 1081    7
# 24      6
# Name: quality, dtype: int64

# %%
x.shape
# Out:
# (1599, 11)

# %% [markdown]
# 1599 rows and 11 cloumns in x.

# %%
y.shape
# Out:
# (1599,)

# %% [markdown]
# 1599 rows in y.

# %% [markdown]
# # Removing the skewness

# %%
from sklearn.preprocessing import power_transform, PowerTransformer

# %%
PowerTransformer()
# Out:
# PowerTransformer()

# %%
x_new=power_transform(x)

# %%
x_new
# Out:
# array([[-4.42665887e-01,  9.95541630e-01, -1.53110932e+00, ...,
#          1.27568965e+00, -5.81649810e-01, -1.07502541e+00],
#        [-1.61307687e-01,  1.77129873e+00, -1.53110932e+00, ...,
#         -7.09517433e-01,  3.95139954e-01, -5.00859609e-01],
#        [-1.61307687e-01,  1.26980139e+00, -1.25535866e+00, ...,
#         -3.10054073e-01,  1.83771552e-01, -5.00859609e-01],
#        ...,
#        [-1.36436736e+00,  3.87065014e-04, -6.83293826e-01, ...,
#          7.18868617e-01,  8.20841495e-01,  7.34557526e-01],
#        [-1.76745837e+00,  7.28552770e-01, -7.43826364e-01, ...,
#          1.63859528e+00,  5.88343819e-01, -1.87998601e-02],
#        [-1.66263981e+00, -1.32045850e+00,  1.03107021e+00, ...,
#          5.29831617e-01,  2.56369273e-01,  7.34557526e-01]])

# %%
#checking skewness

x=pd.DataFrame(x_new,columns=x.columns).skew()

# %%
x
# Out:
# fixed acidity           0.002529
# volatile acidity        0.003099
# citric acid             0.017788
# residual sugar         -0.015715
# chlorides              -0.151304
#                           ...
# total sulfur dioxide   -0.003752
# density                -0.005054
# pH                     -0.002823
# sulphates               0.009985
# alcohol                 0.112372
# Length: 11, dtype: float64

# %% [markdown]
# Observation:
#
# skewness has been removed.

# %% [markdown]
# # Checking Outliers

# %%
data.plot(kind="box",subplots=True,layout=(2,7))
# Out:
# fixed acidity          AxesSubplot(0.125,0.536818;0.0945122x0.343182)
# volatile acidity    AxesSubplot(0.238415,0.536818;0.0945122x0.343182)
# citric acid         AxesSubplot(0.351829,0.536818;0.0945122x0.343182)
# residual sugar      AxesSubplot(0.465244,0.536818;0.0945122x0.343182)
# chlorides           AxesSubplot(0.578659,0.536818;0.0945122x0.343182)
#                                           ...
# density                   AxesSubplot(0.125,0.125;0.0945122x0.343182)
# pH                     AxesSubplot(0.238415,0.125;0.0945122x0.343182)
# sulphates              AxesSubplot(0.351829,0.125;0.0945122x0.343182)
# alcohol                AxesSubplot(0.465244,0.125;0.0945122x0.343182)
# quality                AxesSubplot(0.578659,0.125;0.0945122x0.343182)
# Length: 12, dtype: object

# %% [markdown]
# Observation:
#
# Outliers present in data.

# %% [markdown]
# # Removing Outliers

# %%
from scipy.stats import zscore

# %%
new_data=np.array(data)

# %%
data
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
y.shape
# Out:
# (1599,)

# %%
z=np.abs(zscore(data))

# %%
z
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0          0.528360          0.961877     1.391472        0.453218   0.243707
# 1          0.298547          1.967442     1.391472        0.043416   0.223875
# 2          0.298547          1.297065     1.186070        0.169427   0.096353
# 3          1.654856          1.384443     1.484154        0.453218   0.264960
# 4          0.528360          0.961877     1.391472        0.453218   0.243707
# ...             ...               ...          ...             ...        ...
# 1594       1.217796          0.403229     0.980669        0.382271   0.053845
# 1595       1.390155          0.123905     0.877968        0.240375   0.541259
# 1596       1.160343          0.099554     0.723916        0.169427   0.243707
# 1597       1.390155          0.654620     0.775267        0.382271   0.264960
# 1598       1.332702          1.216849     1.021999        0.752894   0.434990
#
# ...

# %%
thereshold=3
print(np.where(z>3))
# Out:
# (array([  13,   14,   15,   15,   17,   17,   19,   33,   38,   42,   43,
#          45,   57,   81,   81,   83,   86,   88,   91,   92,   95,  106,
#         106,  109,  120,  126,  127,  142,  144,  147,  151,  151,  151,
#         151,  163,  164,  169,  169,  181,  199,  226,  226,  240,  243,
#         244,  258,  258,  274,  281,  291,  324,  325,  339,  340,  347,
#         354,  374,  381,  391,  396,  396,  400,  400,  442,  442,  451,
#         459,  467,  480,  480,  494,  515,  517,  544,  554,  554,  555,
#         555,  557,  557,  568,  584,  588,  591,  595,  608,  614,  636,
#         639,  649,  649,  651,  652,  652,  652,  672,  672,  684,  690,
#         690,  692,  692,  695,  723,  724,  730,  754,  776,  777,  795,
#         821,  832,  836,  837,  889,  899,  911,  917,  923,  925,  926,
#         982, 1017, 1018, 1043, 1051, 1051, 1071, 1074, 1079, 1079, 1081,
#        1081, 1111, 1114, 1131, 1154, 1165, 1175, 1186, 1231, 1235, 1244,
# ...

# %%
new_data=data[(z<3).all(axis=1)]
new_data
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
new_data.shape
# Out:
# (1451, 12)

# %%
data.shape
# Out:
# (1599, 12)

# %%
data=new_data

# %%
data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
x=data.iloc[:,:-1]
x.sample()
# Out:
#      fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 581           12.3               0.5         0.49             2.2      0.089
#
#      free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 581                  5.0                  14.0   1.0002  3.19       0.44
#
#      alcohol
# 581      9.6

# %%
y=data.iloc[:,-1]
y.sample()
# Out:
# 1014    6
# Name: quality, dtype: int64

# %%
x.shape
# Out:
# (1451, 11)

# %%
y.shape
# Out:
# (1451, 1)

# %% [markdown]
# Observation:
#
# Outliers are removed.

# %% [markdown]
# # MULTICOLLINEARITY WITH VARIANCE INFLATION FACTOR

# %%
from scipy import stats
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
x.shape[1]
# Out:
# 11

# %%
def calc_vif(x):
    vif=pd.DataFrame()
    vif["variables"]=x.columns
    vif["VIF FACTOR"]=[variance_inflation_factor(x.values,i) for i in range(x.shape[1])]
    return(vif)

# %%
calc_vif(x)
# Out:
#                variables   VIF FACTOR
# 0          fixed acidity    89.002451
# 1       volatile acidity    19.579511
# 2            citric acid     9.358017
# 3         residual sugar     9.927999
# 4              chlorides    18.125560
# ..                   ...          ...
# 6   total sulfur dioxide     6.956718
# 7                density  1696.645871
# 8                     pH  1242.149186
# 9              sulphates    31.740424
# 10               alcohol   141.935926
#
# [11 rows x 2 columns]

# %% [markdown]
# Observation:
#
# density and ph have highest vif factor.it means we shold drop some columns.

# %%
x=data.drop("density",axis=1)

# %%
x.head(2)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70          0.0             1.9      0.076
# 1            7.8              0.88          0.0             2.6      0.098
#
#    free sulfur dioxide  total sulfur dioxide    pH  sulphates  alcohol  \
# 0                 11.0                  34.0  3.51       0.56      9.4
# 1                 25.0                  67.0  3.20       0.68      9.8
#
#    quality
# 0        5
# 1        5

# %%
calc_vif(x)
# Out:
#                variables  VIF FACTOR
# 0          fixed acidity   50.188470
# 1       volatile acidity   20.046483
# 2            citric acid    9.350248
# 3         residual sugar    9.862951
# 4              chlorides   17.544053
# ..                   ...         ...
# 6   total sulfur dioxide    6.730880
# 7                     pH  191.576901
# 8              sulphates   33.698403
# 9                alcohol  167.828898
# 10               quality   83.519996
#
# [11 rows x 2 columns]

# %% [markdown]
# Observation:
#
# Now variance factor is very low.

# %% [markdown]
# # Scaling the data

# %%
from sklearn.preprocessing import StandardScaler

# %%
scale=StandardScaler()
x=scale.fit_transform(x)
x
# Out:
# array([[-0.55292997,  1.05091371, -1.39039974, ..., -0.63645843,
#         -0.99985592, -0.84412477],
#        [-0.3099004 ,  2.11933582, -1.39039974, ...,  0.2883529 ,
#         -0.6081737 , -0.84412477],
#        [-0.3099004 ,  1.40705441, -1.18083057, ...,  0.05715007,
#         -0.6081737 , -0.84412477],
#        ...,
#        [-1.22126131, -0.07686519, -0.70929993, ...,  0.82782618,
#          0.56687296,  0.43573421],
#        [-1.46429088,  0.72445139, -0.76169222, ...,  0.51955574,
#         -0.21649148, -0.84412477],
#        [-1.40353349, -1.26400088,  1.07203802, ...,  0.13421768,
#          0.56687296,  0.43573421]])

# %% [markdown]
# # Spliting the data

# %%
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier

from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
x=data.iloc[:,:-1]
x
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
x.shape
# Out:
# (1451, 11)

# %%
y=data.iloc[:,-1]

# %%
y
# Out:
# 0       5
# 1       5
# 2       5
# 3       6
# 4       5
#        ..
# 1594    5
# 1595    6
# 1596    6
# 1597    5
# 1598    6
# Name: quality, Length: 1451, dtype: int64

# %%
y.shape
# Out:
# (1451,)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=53)

# %%
x_train.shape
# Out:
# (1160, 11)

# %%
x_test.shape
# Out:
# (291, 11)

# %%
y_train.shape
# Out:
# (1160,)

# %%
y_test.shape
# Out:
# (291,)

# %%
mnb=MultinomialNB()
mnb.fit(x_train,y_train)
predmnb=mnb.predict(x_test)
print(accuracy_score(y_test,predmnb))
print(confusion_matrix(y_test,predmnb))
print(classification_report(y_test,predmnb))
# Out:
# 0.4536082474226804
# [[ 0  3  2  2  0]
#  [ 0 70 36 25  0]
#  [ 0 34 48 35  0]
#  [ 0  4 15 14  0]
#  [ 0  0  1  2  0]]
#               precision    recall  f1-score   support
#
#            4       0.00      0.00      0.00         7
#            5       0.63      0.53      0.58       131
#            6       0.47      0.41      0.44       117
#            7       0.18      0.42      0.25        33
#            8       0.00      0.00      0.00         3
#
#     accuracy                           0.45       291
#    macro avg       0.26      0.27      0.25       291
# weighted avg       0.49      0.45      0.47       291

# %%
dtc=DecisionTreeClassifier()
dtc.fit(x_train,y_train)
dtcpred=dtc.predict(x_test)
print(accuracy_score(y_test,dtcpred))
print(confusion_matrix(y_test,dtcpred))
print(classification_report(y_test,dtcpred))
# Out:
# 0.6426116838487973
# [[ 2  3  2  0  0]
#  [ 7 92 30  2  0]
#  [ 2 29 65 21  0]
#  [ 0  1  5 27  0]
#  [ 0  0  0  2  1]]
#               precision    recall  f1-score   support
#
#            4       0.18      0.29      0.22         7
#            5       0.74      0.70      0.72       131
#            6       0.64      0.56      0.59       117
#            7       0.52      0.82      0.64        33
#            8       1.00      0.33      0.50         3
#
#     accuracy                           0.64       291
#    macro avg       0.61      0.54      0.53       291
# weighted avg       0.66      0.64      0.64       291

# %%
knn=KNeighborsClassifier()
knn.fit(x_train,y_train)
predknn=knn.predict(x_test)
print(accuracy_score(y_test,predknn))
print(confusion_matrix(y_test,predknn))
print(classification_report(y_test,predknn))
# Out:
# 0.5429553264604811
# [[ 0  4  3  0  0]
#  [ 0 88 41  2  0]
#  [ 2 50 59  6  0]
#  [ 0 11 11 11  0]
#  [ 0  1  1  1  0]]
#               precision    recall  f1-score   support
#
#            4       0.00      0.00      0.00         7
#            5       0.57      0.67      0.62       131
#            6       0.51      0.50      0.51       117
#            7       0.55      0.33      0.42        33
#            8       0.00      0.00      0.00         3
#
#     accuracy                           0.54       291
#    macro avg       0.33      0.30      0.31       291
# weighted avg       0.53      0.54      0.53       291

# %%
def svmkernel(ker):
    svc=SVC(kernel=ker)
    svc.fit(x_train,y_train)
    svc.score(x_train,y_train)
    predsvc=svc.predict(x_test)
    print(accuracy_score(y_test,predsvc))
    print(confusion_matrix(y_test,predsvc))
    print(classification_report(y_test,predsvc))

# %%
svmkernel('rbf')
# Out:
# 0.5360824742268041
# [[ 0  1  6  0  0]
#  [ 0 67 64  0  0]
#  [ 0 28 89  0  0]
#  [ 0  4 29  0  0]
#  [ 0  0  3  0  0]]
#               precision    recall  f1-score   support
#
#            4       0.00      0.00      0.00         7
#            5       0.67      0.51      0.58       131
#            6       0.47      0.76      0.58       117
#            7       0.00      0.00      0.00        33
#            8       0.00      0.00      0.00         3
#
#     accuracy                           0.54       291
#    macro avg       0.23      0.25      0.23       291
# weighted avg       0.49      0.54      0.49       291

# %%
svmkernel('linear')
# Out:
# 0.6013745704467354
# [[ 0  5  2  0  0]
#  [ 0 98 32  1  0]
#  [ 0 38 71  8  0]
#  [ 0  5 22  6  0]
#  [ 0  0  2  1  0]]
#               precision    recall  f1-score   support
#
#            4       0.00      0.00      0.00         7
#            5       0.67      0.75      0.71       131
#            6       0.55      0.61      0.58       117
#            7       0.38      0.18      0.24        33
#            8       0.00      0.00      0.00         3
#
#     accuracy                           0.60       291
#    macro avg       0.32      0.31      0.31       291
# weighted avg       0.57      0.60      0.58       291

# %%
svmkernel('poly')
# Out:
# 0.5223367697594502
# [[  0   1   6   0   0]
#  [  0  41  90   0   0]
#  [  0   6 111   0   0]
#  [  0   0  33   0   0]
#  [  0   0   3   0   0]]
#               precision    recall  f1-score   support
#
#            4       0.00      0.00      0.00         7
#            5       0.85      0.31      0.46       131
#            6       0.46      0.95      0.62       117
#            7       0.00      0.00      0.00        33
#            8       0.00      0.00      0.00         3
#
#     accuracy                           0.52       291
#    macro avg       0.26      0.25      0.21       291
# weighted avg       0.57      0.52      0.45       291

# %%
svmkernel('sigmoid')
# Out:
# 0.3402061855670103
# [[ 0  4  3  0  0]
#  [16 63 40 12  0]
#  [ 3 80 33  1  0]
#  [ 0 24  6  3  0]
#  [ 0  3  0  0  0]]
#               precision    recall  f1-score   support
#
#            4       0.00      0.00      0.00         7
#            5       0.36      0.48      0.41       131
#            6       0.40      0.28      0.33       117
#            7       0.19      0.09      0.12        33
#            8       0.00      0.00      0.00         3
#
#     accuracy                           0.34       291
#    macro avg       0.19      0.17      0.17       291
# weighted avg       0.35      0.34      0.33       291

# %% [markdown]
# # Cross val score

# %%
from sklearn.model_selection import cross_val_score

# %%
score=cross_val_score(mnb,x,y,cv=5)
print(score)
print(score.mean())
print(score.std())
# Out:
# [0.50171821 0.47241379 0.44137931 0.36206897 0.41034483]
# 0.43758502192202864
# 0.04854937506160966

# %%
score=cross_val_score(knn,x,y,cv=5)
print(score)
print(score.mean())
print(score.std())
# Out:
# [0.43298969 0.47931034 0.47931034 0.39310345 0.42758621]
# 0.4424600071098471
# 0.033054141964459056

# %%
score=cross_val_score(dtc,x,y,cv=5)
print(score)
print(score.mean())
print(score.std())
# Out:
# [0.4604811  0.44827586 0.45862069 0.45517241 0.46206897]
# 0.45692380613816796
# 0.004896135775309028

# %%
score=cross_val_score(svc,x,y,cv=5)
print(score)
print(score.mean())
print(score.std())
# Out:
# [0.52233677 0.50344828 0.48275862 0.45517241 0.45517241]
# 0.4837776987794763
# 0.026500176361893342

# %% [markdown]
# # Grid Search Cv

# %%
from sklearn.model_selection import GridSearchCV

# %%
dtc=DecisionTreeClassifier()

# %%
params={'criterion':["gini","entropy"],"splitter":["best","random"]}

# %%
gd=GridSearchCV(estimator=dtc,param_grid=params,cv=5)

# %%
gd.fit(x,y)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'splitter': ['best', 'random']})

# %%
gd.best_params_
# Out:
# {'criterion': 'gini', 'splitter': 'random'}

# %%
gd.best_score_
# Out:
# 0.4693399691906624

# %%
dtc=DecisionTreeClassifier(criterion='gini', splitter='random')
dtc.fit(x_train,y_train)
dtcpred=dtc.predict(x_test)
print(accuracy_score(y_test,dtcpred))
print(confusion_matrix(y_test,dtcpred))
print(classification_report(y_test,dtcpred))
# Out:
# 0.6460481099656358
# [[ 0  4  1  2  0]
#  [ 4 91 32  3  1]
#  [ 0 27 77 13  0]
#  [ 0  3 11 19  0]
#  [ 0  1  1  0  1]]
#               precision    recall  f1-score   support
#
#            4       0.00      0.00      0.00         7
#            5       0.72      0.69      0.71       131
#            6       0.63      0.66      0.64       117
#            7       0.51      0.58      0.54        33
#            8       0.50      0.33      0.40         3
#
#     accuracy                           0.65       291
#    macro avg       0.47      0.45      0.46       291
# weighted avg       0.64      0.65      0.64       291

# %%
knn=KNeighborsClassifier()

# %%
param={'weights':["uniform","distance"],"algorithm":["auto","bell_tree","kd_tree","brute"]}

# %%
gdknn=GridSearchCV(knn,param)

# %%
gdknn.fit(x,y)
# Out:
# GridSearchCV(estimator=KNeighborsClassifier(),
#              param_grid={'algorithm': ['auto', 'bell_tree', 'kd_tree', 'brute'],
#                          'weights': ['uniform', 'distance']})

# %%
gdknn.best_params_
# Out:
# {'algorithm': 'auto', 'weights': 'distance'}

# %%
gdknn.best_score_
# Out:
# 0.4500201445668918

# %%
knn=KNeighborsClassifier(algorithm='auto',weights='distance')
knn.fit(x_train,y_train)
predknn=knn.predict(x_test)
print(accuracy_score(y_test,predknn))
print(confusion_matrix(y_test,predknn))
print(classification_report(y_test,predknn))
# Out:
# 0.6357388316151202
# [[ 0  4  3  0  0]
#  [ 0 92 39  0  0]
#  [ 2 30 74 11  0]
#  [ 0  9  6 18  0]
#  [ 0  0  1  1  1]]
#               precision    recall  f1-score   support
#
#            4       0.00      0.00      0.00         7
#            5       0.68      0.70      0.69       131
#            6       0.60      0.63      0.62       117
#            7       0.60      0.55      0.57        33
#            8       1.00      0.33      0.50         3
#
#     accuracy                           0.64       291
#    macro avg       0.58      0.44      0.48       291
# weighted avg       0.63      0.64      0.63       291

# %% [markdown]
# Observation:
#
# DecisionTreeClassifier is best model red wine quality test data.
